# %% [markdown]
# # Parametrización espectral
#
# ***
#
# ![voyteklab](./data/voyteklab.png)
#
# ***
#
#
# ## 03 - Datos reales y análisis relacionado con eventos
#
# Tutorial escrito por Eena Kosik. Editado por Sydney Smith y Quirine Van Engen.
#
# <br><br>
#
#
# Ahora que ya tienes una comprensión básica del algoritmo y de cómo puede aplicarse a datos simulados, apliquemos lo aprendido a **datos reales**.
#
# En lugar de analizar múltiples canales y sujetos, usaremos *un* canal intracraneal de corteza visual de una persona sometida a cirugía por epilepsia. Este registro se obtuvo con electrocorticografía (ECoG), que utiliza una rejilla con múltiples electrodos sobre la corteza cerebral, como puedes visualizar en la figura de abajo.
#
# En este experimento, el sujeto realizaba una tarea de estímulos visuales, en la que debía presionar un botón si aparecía un estímulo objetivo en la pantalla. Por ello, estos datos se dividen en tres tipos de eventos: estímulos estándar (no objetivo), estímulos objetivo y los momentos en que el sujeto respondió.

# %% [markdown]
# ![image-asset.png](./data/image-asset.png)

# %% [markdown]
# ## Instalar paquetes necesarios y clonar el repositorio (para Colab)

# %%
# # Paquetes ncesarios
# !pip install neurodsp
# !pip install fooof

# # Clonar repo
# !git clone https://github.com/voytekresearch/spr.git
# %cd spr/tutorials/01_specparam

# %% [markdown]
# ## Importaciones

# %%
# Paquetes de Python
import numpy as np
import scipy.io as sio

# Neurodsp 
from neurodsp import spectral

# SpecParam (FOOOF)  
from fooof import FOOOF, FOOOFGroup
from fooof.analysis import get_band_peak_fm, get_band_peak_fg

# Para las figuras
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # high res plotting

# %% [markdown]
# ## Cargar datos

# %%
# We are setting the sampling frequency here. The data is sampled at 1000 Hz.
fs = 1000 

# Load the channel and the event indices.
data = sio.loadmat('data/ecog_data.mat', squeeze_me=True)
sta = data['sta'] # Standard event
tar = data['tar'] # Target event
resp = data['resp'] # Response times
data = data['data'] # Neural data from one ECoG channel

# %% [markdown]
# ## Visualizar datos de series temporales
#
# Cuando trabajamos con datos reales, siempre es importante visualizar cada paso del proceso y asegurarnos de entender los datos. Un buen primer paso es graficar parte de la serie temporal.

# %%
# Plot a section of the data in the time domain.
t = np.arange(len(data))/fs
plt.plot(t, data)
plt.xlim((15,18))
plt.xlabel('Time (s)')
plt.ylabel('Voltage')
plt.show()

# %% [markdown]
# ## Calcular y graficar el espectro de potencia
#
# Al observar visualmente la serie temporal, quizá puedas notar algunas oscilaciones neurales. Sin embargo, para tener una idea más completa de los datos, puedes calcular el espectro de potencia (power spectrum) y ver cuánta potencia hay en cada banda de frecuencia.
#
# Estamos usando la función `compute_spectrum` a través de `neurodsp`, que por defecto usa el método de Welch. Este método calcula la transformada rápida de Fourier (FFT) sobre ventanas de los datos y promedia las FFT de esas ventanas para suavizar el espectro de potencia.

# %%
# Compute power spectrum
freq, psd = spectral.compute_spectrum(data, fs=fs, method='welch', window='hann')

# %%
# Plot power spectrum
plt.plot(freq, psd)
plt.xlabel('Frequency (Hz)')
plt.ylabel('Power ($\mu$V$^2$/Hz)')
plt.xlim((0, 250))
plt.show()

# %% [markdown]
# Aquí el aspecto '1/f' de los datos es claro: las frecuencias más bajas tienen una potencia exponencialmente mayor que las frecuencias más altas. Ni siquiera podemos ver bien la potencia por encima de ~100 Hz.
#
# También podemos observar una gran ráfaga de potencia alrededor de 10 Hz. Esta es una oscilación alpha muy clara y fuerte en la corteza visual. También vemos una pequeña elevación de potencia alrededor de 20 Hz. Sin embargo, esto quizá no sea una oscilación beta 'real' de ~20 Hz, debido a efectos armónicos. Esto se discutirá más adelante en los notebooks de Bycycle.

# %%
# Plot again, but log scale the power

plt.semilogy(freq, psd)
plt.xlabel('Frequency (Hz)')
plt.ylabel('Log Scale Power ($\mu$V$^2$/Hz)')
plt.xlim((0, 250))
plt.show()

# %% [markdown]
# Ten en cuenta que, si aplicamos escala logarítmica a la potencia (eje y), empieza a parecer una línea recta, excepto por las elevaciones oscilatorias y los filtros notch.
#
# Hagamos zoom solo en la región por debajo de 60 Hz...

# %%
# Plot again, but log scale the power, zoom in below 60 Hz, and log scale the frequency axis

plt.plot(freq, np.log10(psd))
plt.xlabel('Log Scale Frequency (Hz)')
plt.ylabel('Log Scale Power ($\mu$V$^2$/Hz)')
plt.xlim((1, 55))
plt.ylim((0.3, 2.5))
plt.show()

# %% [markdown]
# ¡Ahora sí se ve un espectro de potencia hermoso! Usemos el modelo SpecParam (FOOOF) para ajustar este espectro y extraer algunos parámetros interesantes.

# %% [markdown]
# ## Ajustar el modelo SpecParam a tu espectro de potencia

# %%
# **SAME SETTINGS AS SIMULATION NOTEBOOK**
# In this case, we set a peak width limit to be higher than 2 frequencies wide AND smaller than 8 frequencies wide.
# Furthermore, we're setting a hard threshold minimum for the peak height to be considered an oscillation.
specparam_sets = {'peak_width_limits': [2, 8], 'min_peak_height': 0.1}
freq_range = [1, 40] # Depending on the quality of your data, you might not want to fit very high frequencies

# Define the frequency ranges you consider to be alpha oscillations
alpha_range = [8, 12]

# Initialize models
model = FOOOF(**specparam_sets)

# Fit models
model.fit(freq, psd, freq_range=freq_range)

# %%
model.report()
# Out:
# ...
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 40 Hz
#                                  Frequency Resolution is 1.00 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           2.5465, 1.1505
#
#                                        2 peaks were found:
#                                 CF:   8.07, PW:  0.781, BW:  4.36
#                                 CF:  16.18, PW:  0.451, BW:  8.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9829
#                                     Error of the fit is 0.0557
#
# ...

# %% [markdown]
# ## Extraer parámetros para los análisis

# %%
# Extract the aperiodic parameters (exponent and offset)
aper = model.get_params('aperiodic_params')

# Extract the periodic paramaters (center frequency, aperidic adjusted power, band width)
per = model.get_params('peak_params')

# %%
# Print out model fit results
print('\033[1m' + 'Aperiodic parameters:' + '\033[0m' + '\n \t The aperiodic exponent (slope) is:', round(aper[0],3))
print('\t The aperiodic offset is:', round(aper[1],3))
print('\033[1m' + 'Periodic parameters:' + '\033[0m' + '\n \t There are ' + str(model.n_peaks_) + ' peaks found in this model.')

for idx, peak in enumerate(per):
    print('\t Peak #', str(idx+1))
    print('\t \t The center frequency is ' + str(round(peak[0],3)))
    print('\t \t The aperiodic adjusted power is ' + str(round(peak[1],3)))
    print('\t \t The bandwidth is ' + str(round(peak[2],3)))
# Out:
# Aperiodic parameters:
#  	 The aperiodic exponent (slope) is: 2.547
# 	 The aperiodic offset is: 1.151
# Periodic parameters:
#  	 There are 2 peaks found in this model.
# 	 Peak # 1
# 	 	 The center frequency is 8.07
# 	 	 The aperiodic adjusted power is 0.781
# 	 	 The bandwidth is 4.358
# 	 Peak # 2
# 	 	 The center frequency is 16.178
# 	 	 The aperiodic adjusted power is 0.451
# 	 	 The bandwidth is 8.0

# %% [markdown]
# Como puedes ver, hay dos parámetros aperiódicos. El primero es el exponente, o pendiente, de la señal aperiódica. El segundo es el offset, que corresponde al desplazamiento global hacia arriba o abajo de todo el espectro de potencia.
#
# También hay tres parámetros periódicos para cada pico detectado en el espectro. El primer parámetro es la frecuencia central de cada pico medida en frecuencia; el segundo es la potencia de cada pico, ajustada por la señal aperiódica, medida en potencia; y el tercero es el ancho de banda de cada pico, medido en frecuencia.

# %% [markdown]
# ## Diferencias en el espectro de potencia relacionadas con eventos
#
# Aunque es interesante observar el espectro de potencia global y ver las oscilaciones alpha prominentes, tiene sentido examinar diferencias relacionadas con eventos cuando hay una tarea involucrada.
#
# Como comentamos al principio de este notebook, este sujeto de ECoG responde a estímulos visuales y presiona un botón si el estímulo es considerado un objetivo. Por lo tanto, podemos segmentar los datos en trials con base en cada evento y promediar esos trials según el tipo de evento. En la figura de abajo haremos eso y graficaremos lo que se conoce como un potencial relacionado con eventos (ERP), comparando los trials estándar versus los trials objetivo.

# %%
def event_related(data, fs, indices, window, subtract_mean=None):
    """Take an input time series, vector of event indices, and window sizes,
    and return a 2d matrix of windowed trials around the event indices.
    
    Parameters
    ----------
    data : array-like 1d
        Voltage time series
    data : float
        Data sampling rate (Hz)
    indices : array-like 1d of integers
        Indices of event onset indices
    window : tuple (intengers)
        Window (in ms) around event onsets
    subtract_mean : tuple (intengers), optional
        if present, subtract the mean value in the subtract_mean window for each
        trial from that trial's time series (this is a trial-by-trial baseline)
    
    Returns
    -------
    event_related_matrix : array-like 2d
        Event-related times series around each index
        Each row is a separate event
    """
    
    # convert times (in ms) to indices of points along the array
    def windows_to_indices(fs, window_times):
        conversion_factor = (1/fs)*1000 # convert from time points to ms
        window_times = np.floor(np.asarray(window_times)/conversion_factor) # coonvert
        window_times = window_times.astype(int) # turn to ints
        
        return window_times
    
    window_idx = windows_to_indices(fs, window) # convert times (in ms) to indices
    inds = indices + np.arange(window_idx[0],window_idx[1])[:,None] # build matrix of indices
    event_times = np.arange(window[0], window[1], fs/1000)
    
    event_related_matrix = data[inds] # grab the data
    event_related_matrix = np.squeeze(event_related_matrix).T # make sure it's in the right format
    
    # baseline, if requested
    if subtract_mean is not None:
        basewin = [0,0]
        basewin[0] = np.argmin(np.abs(event_times-subtract_mean[0]))
        basewin[1] = np.argmin(np.abs(event_times-subtract_mean[1]))
        event_related_matrix = event_related_matrix - event_related_matrix[:, basewin[0]:basewin[1]].mean(axis=1, keepdims=True)
    
    return event_times, event_related_matrix

event_times, sta_erp = event_related(data, fs, sta, (-500,500), (-100,0))
event_times, tar_erp = event_related(data, fs, tar, (-500,500), (-100,0))

plt.plot(event_times, np.mean(sta_erp,0), 'k', label='standard')
plt.plot(event_times, np.mean(tar_erp,0), 'b', label='target')
plt.legend()
plt.show()

# %% [markdown]
# A partir de esta gráfica, parece que el inicio de los estímulos objetivo y estándar produce un potencial relacionado con eventos (ERP) grande, y que estos ERP podrían diferir dependiendo de la condición experimental. Sin embargo, cuando pensamos en las contribuciones de la actividad aperiódica a las señales neurales, pueden surgir varias preguntas. Por ejemplo:
#
# 1) ¿La actividad aperiódica cambia de una manera relacionada con el evento?
#
# 2) ¿Cómo podrían los cambios en la actividad aperiódica estar afectando nuestras interpretaciones de los cambios relacionados con eventos en la potencia por banda?
#
# 3) ¿Podría la actividad aperiódica estar cambiando de manera diferencial según la condición conductual?
#
# Para cuantificar esto, comenzaremos con un análisis básico pre- vs. post-evento. Dividiremos los datos en dos ventanas, 2 segundos antes del inicio del evento y 2 segundos después, calcularemos los espectros de potencia para estas dos ventanas y compararemos las características espectrales.

# %%
# compute event windows with no baseline
event_times, pre_sta_erp = event_related(data, fs, sta, (-1*fs,0))
event_times, post_sta_erp = event_related(data, fs, sta, (0,1*fs))
event_times, pre_tar_erp = event_related(data, fs, tar, (-1*fs,0))
event_times, post_tar_erp = event_related(data, fs, tar, (0,1*fs))

# %%
# caclculate power spectra for 2 time windows and 2 conditions
freqs, pre_sta_psd = spectral.compute_spectrum_welch(pre_sta_erp, fs, nperseg=fs*1, noverlap=fs/2, f_range=[2,52])
freqs, post_sta_psd = spectral.compute_spectrum_welch(post_sta_erp, fs, nperseg=fs*1, noverlap=fs/2, f_range=[2,52])
freqs, pre_tar_psd = spectral.compute_spectrum_welch(pre_tar_erp, fs, nperseg=fs*1, noverlap=fs/2, f_range=[2,52])
freqs, post_tar_psd = spectral.compute_spectrum_welch(post_tar_erp, fs, nperseg=fs*1, noverlap=fs/2, f_range=[2,52])

# %%
# plot raw psds

fig, ax = plt.subplots(1,2, figsize=[12,5])
ax = ax.ravel()

ax[0].plot(freqs, pre_sta_psd.mean(axis=0), label='baseline')
ax[0].plot(freqs, post_sta_psd.mean(axis=0), label='stimulus')

ax[1].plot(freqs, pre_tar_psd.mean(axis=0), label='baseline')
ax[1].plot(freqs, post_tar_psd.mean(axis=0), label='stimulus')

ax[0].set_title('Standard', fontsize=18)
ax[0].set_xlabel('Log Scale Frequency (Hz)', fontsize=12)
ax[0].set_ylabel('Log Scale Power ($\mu$V$^2$/Hz)',  fontsize=12)
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].legend();
ax[1].set_title('Target', fontsize=18)
ax[1].set_xlabel('Log Scale Frequency (Hz)',  fontsize=12)
ax[1].set_ylabel('Log Scale Power ($\mu$V$^2$/Hz)', fontsize=12)
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].legend();

# %% [markdown]
# ### Al igual que en el análisis ERP, estos espectros de potencia han sido promediados a través de trials, pero ahora revisémoslos trial por trial usando **FOOOFGroup**

# %%
# In this case, we set a peak width limit to be higher than 2 frequencies wide AND smaller than 8 frequencies wide.
# Furthermore, we're setting a hard threshold minimum for the peak height to be considered an oscillation.
specparam_sets = {'peak_width_limits': [2, 8], 'min_peak_height': 0.1}
freq_range = [1, 40]

# Define the frequency ranges you consider to be theta or alpha oscillations
alpha_range = [8, 12]

# Initialize models
pre_sta_model = FOOOFGroup(**specparam_sets)
post_sta_model = FOOOFGroup(**specparam_sets)

# Fit models
pre_sta_model.fit(freqs, pre_sta_psd, freq_range=freq_range)
post_sta_model.fit(freqs, post_sta_psd, freq_range=freq_range)
# Out:
# Running FOOOFGroup across 380 power spectra.
# /Users/jerjesaguirrechavez/Desktop/Desktop_Current/UCSD/Voytek Lab/spr/spr_env/lib/python3.9/site-packages/scipy/optimize/_lsq/trf.py:234: RuntimeWarning: divide by zero encountered in divide
#   Delta = norm(x0 * scale_inv / v**0.5)
# /Users/jerjesaguirrechavez/Desktop/Desktop_Current/UCSD/Voytek Lab/spr/spr_env/lib/python3.9/site-packages/scipy/optimize/_lsq/common.py:49: RuntimeWarning: invalid value encountered in scalar divide
#   t2 = c / q
# /Users/jerjesaguirrechavez/Desktop/Desktop_Current/UCSD/Voytek Lab/spr/spr_env/lib/python3.9/site-packages/scipy/optimize/_lsq/trf.py:363: RuntimeWarning: invalid value encountered in scalar divide
#   alpha *= Delta / Delta_new
# /Users/jerjesaguirrechavez/Desktop/Desktop_Current/UCSD/Voytek Lab/spr/spr_env/lib/python3.9/site-packages/scipy/optimize/_lsq/trf.py:234: RuntimeWarning: divide by zero encountered in divide
#   Delta = norm(x0 * scale_inv / v**0.5)
# ...

# %% [markdown]
# ## Inspeccionar los ajustes del modelo

# %% [markdown]
# Usando el comando `plot()`, podemos inspeccionar los ajustes del modelo. SpecParam calcula automáticamente el ajuste del modelo con 2 medidas diferentes: 1) `Error`, 2) `Rˆ2`.
#
# Esta gráfica también te mostrará todos los ajustes aperiódicos y las frecuencias centrales de los picos que encontró.
#
# Recomendamos mucho graficar siempre estas figuras, porque te dan una primera impresión de qué tan bien el modelo se ajusta a los datos.

# %% [markdown]
# ### Periodo pre-estímulo con FOOOFGroup

# %%
pre_sta_model.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 pre_sta_model.plot()
#
# File ~/Desktop/Desktop_Current/UCSD/Voytek Lab/spr/spr_env/lib/python3.9/site-packages/fooof/objs/group.py:403, in FOOOFGroup.plot(self, save_fig, file_name, file_path)
#     400 @copy_doc_func_to_method(plot_fg)
#     401 def plot(self, save_fig=False, file_name=None, file_path=None):
# --> 403     plot_fg(self, save_fig, file_name, file_path)
#
# File ~/Desktop/Desktop_Current/UCSD/Voytek Lab/spr/spr_env/lib/python3.9/site-packages/fooof/core/modutils.py:180, in check_dependency.<locals>.wrap.<locals>.wrapped_func(*args, **kwargs)
#     177 if not dep:
#     178     raise ImportError("Optional FOOOF dependency " + name + \
#     179                       " is required for this functionality.")
# --> 180 func(*args, **kwargs)
#
# ...

# %% [markdown]
# ### Periodo post-estímulo con FOOOFGroup

# %%
post_sta_model.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 post_sta_model.plot()
#
# File ~/Desktop/Desktop_Current/UCSD/Voytek Lab/spr/spr_env/lib/python3.9/site-packages/fooof/objs/group.py:403, in FOOOFGroup.plot(self, save_fig, file_name, file_path)
#     400 @copy_doc_func_to_method(plot_fg)
#     401 def plot(self, save_fig=False, file_name=None, file_path=None):
# --> 403     plot_fg(self, save_fig, file_name, file_path)
#
# File ~/Desktop/Desktop_Current/UCSD/Voytek Lab/spr/spr_env/lib/python3.9/site-packages/fooof/core/modutils.py:180, in check_dependency.<locals>.wrap.<locals>.wrapped_func(*args, **kwargs)
#     177 if not dep:
#     178     raise ImportError("Optional FOOOF dependency " + name + \
#     179                       " is required for this functionality.")
# --> 180 func(*args, **kwargs)
#
# ...

# %% [markdown]
# ¿Qué notas acerca de las métricas de calidad del ajuste?
#
# ¿Qué aspecto de estos datos podría estar causando el error más alto?

# %% [markdown]
# ### Extraer y revisar los parámetros

# %%
# Extract the aperiodic parameters (exponent and offset)
exp_pre_sta = pre_sta_model.get_params('aperiodic_params', 'exponent')
exp_post_sta = post_sta_model.get_params('aperiodic_params', 'exponent')
offset_pre_sta = pre_sta_model.get_params('aperiodic_params', 'offset')
offset_post_sta = post_sta_model.get_params('aperiodic_params', 'offset')

# Extract the periodic paramaters (aperidic adjusted power, band width, center frequency)
alpha_pre_sta = get_band_peak_fg(pre_sta_model, band=alpha_range)
alpha_post_sta = get_band_peak_fg(post_sta_model, band=alpha_range)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 8
#       5 offset_post_sta = post_sta_model.get_params('aperiodic_params', 'offset')
#       7 # Extract the periodic paramaters (aperidic adjusted power, band width, center frequency)
# ----> 8 alpha_pre_sta = get_band_peak_fg(pre_sta_model, band=alpha_range)
#       9 alpha_post_sta = get_band_peak_fg(post_sta_model, band=alpha_range)
#
# File ~/Desktop/Desktop_Current/UCSD/Voytek Lab/spr/spr_env/lib/python3.9/site-packages/fooof/analysis/periodic.py:100, in get_band_peak_fg(fg, band, threshold, thresh_param, attribute)
#      51 def get_band_peak_fg(fg, band, threshold=None, thresh_param='PW', attribute='peak_params'):
#      52     """Extract peaks from a band of interest from a FOOOFGroup object.
#      53
#      54     Parameters
#    (...)
# ...

# %%
# Let's see what our parameters look like. We have a list of all the exponents for the  pre stimulus standard trials
exp_pre_sta
# Out:
# array([ 1.20256743,  1.63237293,  1.11908053,  1.28783562,  0.6302214 ,
#         1.57145698,  1.36520301,  0.91745046,  1.31384906,  1.40929311,
#         1.51073698,  0.95617887,  1.26799719,  1.48378131,  1.51635171,
#         0.23268847,  0.85970578,  1.1245863 ,  0.49515361,  2.38164429,
#         0.85378087,  1.9946274 ,  0.5313308 ,  1.68506627,  1.00343392,
#         2.28493697,  0.98968705,  1.55498295,  1.54191292,  0.49684033,
#         1.13880478,  1.46173029,  1.3182549 ,  1.62920489,  1.12504564,
#        -0.4123116 ,  0.1431409 ,  2.66990837,  0.59008367,  1.32264108,
#         0.50664826,  1.83966003,  0.81130969,  1.86882215,  1.44928466,
#         1.32950937,  1.46450406,  0.98852091,  1.3155518 ,  2.12180837,
#         1.41663319,  1.89556299,  2.01495866,  1.78304706,  0.18518751,
#         1.67586547,  2.26334377,  0.69302715,  2.05438408,  1.79084897,
#         0.98129994,  1.88827326,  1.33162099,  1.49433233,  0.665293  ,
# ...

# %%
# Let's look at the alpha parameters of the pre stimulus standard trials.
# Here we see 3 columns and rows with the same amount as trials. 
# Look up the 'get_band_peak_fg' to see which parameter is which column ---> SPOILER:  [CF, PW, BW]
alpha_pre_sta
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 # Let's look at the alpha parameters of the pre stimulus standard trials.
#       2 # Here we see 3 columns and rows with the same amount as trials.
#       3 # Look up the 'get_band_peak_fg' to see which parameter is which column ---> SPOILER:  [CF, PW, BW]
# ----> 4 alpha_pre_sta
#
# NameError: name 'alpha_pre_sta' is not defined

# %% [markdown]
# ## Por último, grafiquemos algunas diferencias de parámetros entre la condición 1 y la 2

# %%
# plotting function

def plot_feature_conditions(feature_c1, feature_c2):
        
    x1 = np.ones(len(feature_c1)) * 0.5
    x2 = np.ones(len(feature_c2)) * 1.5
    plt.scatter(x1+np.random.normal(-0.025,0.025,len(feature_c1)), feature_c1, color='teal', alpha=0.3)
    plt.scatter(x2+np.random.normal(-0.025,0.025,len(feature_c2)), feature_c2, color='orange', alpha=0.3)

    plt.plot([x1-0.1, x1+0.1], [np.nanmean(feature_c1), np.nanmean(feature_c1)], lw=7, c='teal')
    plt.plot([x2-0.1, x2+0.1], [np.nanmean(feature_c2), np.nanmean(feature_c2)], lw=7, c='orange')

    plt.xlim([0, 2])

    plt.xticks([x1[0], x2[0]], ["pre-stimulus", "post-stimulus"])

# %%
plot_feature_conditions(exp_pre_sta, exp_post_sta)
plt.title('Exponent');

# %% [markdown]
# A simple vista, no parece haber mucha diferencia entre estas dos condiciones en términos de su exponente aperiódico, pero necesitaríamos realizar una prueba estadística para afirmarlo con certeza.

# %%
# To select the alpha aperiodic adjusted power, select all rows from column 2
alpha_pw_pre_sta = alpha_pre_sta[:,1]
alpha_pw_post_sta = alpha_post_sta[:,1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # To select the alpha aperiodic adjusted power, select all rows from column 2
# ----> 2 alpha_pw_pre_sta = alpha_pre_sta[:,1]
#       3 alpha_pw_post_sta = alpha_post_sta[:,1]
#
# NameError: name 'alpha_pre_sta' is not defined

# %%
plot_feature_conditions(alpha_pw_pre_sta, alpha_pw_post_sta)
plt.title('Aperiodic-adjusted alpha power');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 plot_feature_conditions(alpha_pw_pre_sta, alpha_pw_post_sta)
#       2 plt.title('Aperiodic-adjusted alpha power');
#
# NameError: name 'alpha_pw_pre_sta' is not defined

# %%
# To select the alpha center frequency, select all rows from column 1
alpha_cf_pre_sta = alpha_pre_sta[:,1]
alpha_cf_post_sta = alpha_post_sta[:,1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # To select the alpha center frequency, select all rows from column 1
# ----> 2 alpha_cf_pre_sta = alpha_pre_sta[:,1]
#       3 alpha_cf_post_sta = alpha_post_sta[:,1]
#
# NameError: name 'alpha_pre_sta' is not defined

# %%
plot_feature_conditions(alpha_cf_pre_sta, alpha_cf_post_sta)
plt.title('Alpha center frequency');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 plot_feature_conditions(alpha_cf_pre_sta, alpha_cf_post_sta)
#       2 plt.title('Alpha center frequency');
#
# NameError: name 'alpha_cf_pre_sta' is not defined

# %% [markdown]
# Por ahora solo hemos observado la banda alpha canónica. ¿Hay otro rango de frecuencias que podría ser de interés en este análisis, con base en los espectros de potencia y en los picos encontrados usando `FOOOFGroup`?
#
# Si es así, ¡intenta implementarlo por tu cuenta!

# %% [markdown]
# #### Este notebook contiene muchas funciones que facilitan trabajar con resultados de FOOOF (por ejemplo, extraer parámetros de ajustes del modelo). Explóralas por tu cuenta en el [sitio de documentación de FOOOF](https://fooof-tools.github.io/fooof/api.html).
